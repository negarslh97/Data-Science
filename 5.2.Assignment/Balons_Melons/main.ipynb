# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
np.random.seed(42)

balloons = pd.DataFrame({
    'length': np.random.normal(5, 0.5, 600),   
    'width': np.random.normal(4, 0.3, 600),    
    'weight': np.random.normal(0.2, 0.1, 600)  
})
balloons['type'] = 'balloon'  

melons = pd.DataFrame({
    'length': np.random.normal(8, 0.7, 600),  
    'width': np.random.normal(7, 0.5, 600),    
    'weight': np.random.normal(1.5, 0.2, 600) 
})
melons['type'] = 'melon'

# %%
dataset = pd.concat([balloons, melons], ignore_index=True)

print(dataset.head())
# Out:
#      length     width    weight     type
# 0  5.248357  4.227097  0.212522  balloon
# 1  4.930868  3.723350  0.157059  balloon
# 2  5.323844  4.260882  0.212230  balloon
# 3  5.761515  4.406691  0.254330  balloon
# 4  4.882923  4.124030  0.204886  balloon

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

balloons_data = dataset[dataset['type'] == 'balloon']
melons_data = dataset[dataset['type'] == 'melon']

ax.scatter(balloons_data['length'], balloons_data['width'], balloons_data['weight'],
           c='red', label='Balloons', alpha=0.6)

ax.scatter(melons_data['length'], melons_data['width'], melons_data['weight'],
           c='green', label='Melons', alpha=0.6)

ax.set_xlabel('Length')
ax.set_ylabel('Width')
ax.set_zlabel('Weight')
ax.set_title('3D Scatter Plot of Balloons and Melons')
ax.legend()
